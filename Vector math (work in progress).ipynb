# %% [markdown]
# # Vector math
#
#
# ### Contents
# 1. Cosine similarity
# 2. Vector distance: euclidian, manhattan etc.

# %% [markdown]
# ## Cosine similarity with numpy

# %%
## Function
import numpy as np

def cosine_similarity(a, b):
    global similarity
    similarity =  np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))
    return similarity

# Example usage

A = np.array([2, 1, 2, 3, 2, 9])
B = np.array([3, 4, 2, 4, 5, 5])

cosine_similarity(A, B)
print(f"Cosine Similarity: {similarity}")
# Out:
# Cosine Similarity: 0.8188504723485274

# %%
#inspect one vector
print(A)
print(A.ndim)
print(A.shape)
print(type(A))
# Out:
# [2 1 2 3 2 9]
# 1
# (6,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Ask for two points and calculate and plot cosine similarity

# %%
#Define two points

# Choose values [1-10] (integers/floats) to properly plot it below

# point 1
p1x = 4
p1y = 3

#point 2
p2x = 3
p2y = 4

A = np.array([p1x,p1y])
B = np.array([p2x, p2y])

print(A,B)
# Out:
# [4 3] [3 4]

# %%
#
similarity = cosine_similarity(A, B)
print(f"Cosine Similarity: {similarity}")
# Out:
# Cosine Similarity: 0.96

# %%
#plot the points and create a vector from 0,0
# %matplotlib notebook
import matplotlib.pyplot as plt 

#get points and plot them
points_x = p1x, p2x
points_y = p1y, p2y
plt.plot(points_x, points_y, 'o') 

#plot vectors 
plt.quiver([0, 0], [0, 0], [p1x, p2x], [p1y,p2y], angles='xy', scale_units='xy', scale=1)

#plot axes and show it
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
