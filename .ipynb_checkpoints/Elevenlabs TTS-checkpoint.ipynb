# %% [markdown]
# # Elevenlabs Text to Speech with OpenAI and streaming

# %% [markdown]
# ### Contents
# 0. Install packages & setup
# 1. Demo script
#
# ### Sources:
# - www.elevenlabs.io
# - https://github.com/elevenlabs/elevenlabs-python
# - https://twitter.com/flavioschneide/status/1688611094720389120
#
# Requires mpv. On mac you can install it with 'brew install mpv'. On linux and windows you can install it from https://mpv.io/

# %% [markdown]
# ## 0. Install packages and setup

# %%
pip install elevenlabs
# Out:
# Collecting elevenlabs
#   Downloading elevenlabs-0.2.24-py3-none-any.whl (16 kB)
# Requirement already satisfied: ipython>=7.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from elevenlabs) (8.10.0)
# Requirement already satisfied: pydantic<2.0,>=1.10 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from elevenlabs) (1.10.7)
# Requirement already satisfied: websockets>=11.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from elevenlabs) (11.0.1)
# Requirement already satisfied: requests>=2.20 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from elevenlabs) (2.31.0)
# Requirement already satisfied: matplotlib-inline in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (0.1.6)
# Requirement already satisfied: traitlets>=5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (3.0.36)
# Requirement already satisfied: appnope in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (0.1.2)
# Requirement already satisfied: backcall in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (2.15.1)
# Requirement already satisfied: decorator in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (4.4.2)
# Requirement already satisfied: stack-data in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from ipython>=7.0->elevenlabs) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pydantic<2.0,>=1.10->elevenlabs) (4.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.20->elevenlabs) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.20->elevenlabs) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.20->elevenlabs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.20->elevenlabs) (2.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.0->elevenlabs) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.0->elevenlabs) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=7.0->elevenlabs) (0.2.5)
# Requirement already satisfied: pure-eval in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.0->elevenlabs) (0.2.2)
# Requirement already satisfied: asttokens in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.0->elevenlabs) (2.0.5)
# Requirement already satisfied: executing in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.0->elevenlabs) (0.8.3)
# Requirement already satisfied: six in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from asttokens->stack-data->ipython>=7.0->elevenlabs) (1.16.0)
# Installing collected packages: elevenlabs
# Successfully installed elevenlabs-0.2.24
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
import elevenlabs
import config
openai_api_key = config.openai_key
elevenlabs.set_api_key(config.elevenlabs_key)

# %% [markdown]
# ## 1. Demo script

# %%
from elevenlabs import generate, stream

def text_stream():
    yield "Hi,"
    yield "How are you?"
    
    
audio_stream = generate(
    text=text_stream(),
    voice = "Nicole",
    stream = True
)    
stream(audio_stream)
# Out:
# b'\xff\xfbP\xc4\x00\x00\x06t\x01!\xa0\x0c`!>\x0b\xa5\xf4 \x8c`@\x99\x1c\xad7\x1ai\x16Q`\xfb\xde\xb2\xe6\xf2\x05\x01\x04\xcb\xd2\x00\x044\xff\x94vC\xca;\xcf\xa6Q\xc2\x0f\xfbD\xf4u\x9f\')\x9c\xae_!d\xbe\xfe\xe9w\xe0\x80\x8d\xc95\xdbiZ@\xb7\x89W(\xb4xA\x0e\xf0\xc3\x81J-\xd0\x0c^\x10\x85\xe0\x06\x9fr \xe9TN\x08\x87\xc2;\x81\xf1\x00D\xe0>\x04\x0c\x12\xda\x82\x8eT\xfa\xf7\xd5\x97\xbb\xfc\x9e q2\x81\x90@\xbe\xae\x91`\xc0\x9c\xba\xcf\x9c\x0c\x1f&*\x16\x04\x08*\x05\xb6\xe4-$\xa2$!9\xf8(\x84\x9c\xb9\xf2r\x82\x86\x17 \x14\x81d\x05\xe4(*\x07\tG\xd5m\xbfi\xcd\'\x7f\xf2{\xea\x15\x06\xe6\x8d\x1df\xed<\xb6>\x1d\x88\xcf!\\\xff\xfbR\xc4\x1b\x80\x0b-/\'\xa4\x84|\xc2$\x9cg\xf5\x84\xa3\x83\xd0\x04\xd1\x0e\x95\x8b\xee\xa1\x89\xb3)\x14\xbc\xed-\xd0M\x07\xfd|\x83l\xc3\x92\xfb=\n\xd0P\x04\xf43\x1f\xb9)H\xe3q\xc9$m\xa43\xcf\xf0w\x1ft\x8cMY\xa6Vm\xd9\xee%\x93]M\xa9u\xd4zL\xddD\\\x03Pj&\x94\x98\xde\n\xbd"\xc3\xb9(\xa7*b\x12\xd7y\xe4\xbb\x17\x86#\xedm\xfek\x8d\xd5\x00m\x92Z\xd2\xd1Mc\xa8:\x97\xc2\xdb\th\xdee3\x03\x1d\x19\x0bY\x19\x8eF*\xe2\xfa8\x918\xbc\xdb\xaa\x87\\F+\x9c\xd1\xa3\x15\x85*7\x8a\xf7\xc8\x1d\x01\xe4u\xa9\xf7O\x08(|\xbc\x18\x80[_\xffo\xc3\xad\x0f\xcd\xf8\x8e\x1f\xda\x1f\xff\xff\xfb\xed\xb5\xac\x01\xfe\xde<\x8a\xd4\xa5/\x88\xff\xfbR\xc4\x08\x00\x0b\xfc\xc1w\xa7\x98\\1k\x9ajd\xf6\x0e`\xf3\xf0\xef1\xc4\x10\x0b\x04\xd0\x0b\xe9\xf0S\x9b\xc2\xea\x04\xe8u\x95E\x81^\xb2\xc8\xc6\x96\x8b\x01\x91\xfb\x053xq\xa4\x88\xf1\xc5m\rgZe\x88\xd4~(\x08:u\x89\x0f\x18\xe8[\x1c\r\xd2\xda\xdeo\xf32\xd9Z\x00\x18\xdf\x027\xadD`\xc7\x87\xc1:o&R\x00\x02\x00\xb4\x7f\xef\r\xfd\xcf\xe5\x94=D\x84>I\x89\x99\xfaZ\xae\x89C\x8a\x88\x0f\x87\x817B\x13\x82DmBV,\'W\x05_\x9e\xf9\xad\xa0&\x1b\x93\x10\x147;\xd5yxV=\x8f\xdb3\xbd;?\xe4Y sz\xe8Om\xe1&x*\r\xb4\xf7\x08B\x83C\x88i\xa5\xbf\xe93!\xae\xda\xb4X\x00 \x02LMe\xf2\x1e\x08c\xb9\x82\xbb\x06\xff\xfbR\xc4\x08\x80\n\xe1\x93m\xa6\x18G\x19\xa1\xb0,\xf4\xf1\x8aZ)\xc8\x10,\x82\xd20B\x8cA\xa5o\x8c\t\x9d?D;\xbdt\x8fUf\xff\xebE~_\xfa=\x19\t\xe7\x9d\xe4 #%\x0c\x92\xbf\xff\xff\xff\x93_\xd9{U{.`\x85\x1c`s\xadE\x84=\xde\x10\x01i\x16\x002\x08~ \xf5\xc4@\x00\x10\x01)\xb8\xab8\x97a|\xc8\x91h)\x90\xf4\xf2\x85\xe6\x9e)\x0ev\xb6\xcbV+;\x1a\x95\x93-\xedU\x8a\xa9s\xb9\x1b\x18\xc6*\xe0\xde\x89\x16\x10\r\x95\x1b\xfb\xfa\x10\xc6\xfc\xc4\xad\x0e\xfb(U\xb5$B+\x9a\xe1\xedK_\xf5]*\xa9\xb4v\xe8\x9a\xbd\xbd\x01\xd1$wA.\xfc\xac\x11\xb3?PL\xa7\x9cC\x17\x86\x1e\xd7\xa1\x15\xa94\x80\x00\x90\x01$(~\x88\xb2\x18\xc2\xff\xfbR\xc4\x06\x80\x0b\x91\x8fi\xa7\xb0C\xd9\x86\xad\xed\xfd\xa4\t\xb5Ox\xc8N/\xa1!\xda\xeb\x90-\x87G+\xc9C3\n\xe4\xc6\xa2+:[\xde\xb1\xd8\x0c\x89e(c\x80\xb0#\xbb\x7f\xf9\xd9Q\xd7\xe5\xf21\x8e\xea->\x8a\xda\xb3\x99\x7f\xff\xff\xff\xff\xff\xfa#\xb3\xe69\xca\x18\x11\xdc\xed8\x02\xb1\x1e\x86\n\xe4\x06x#mo\x98eA\x10\x15i&HXt\x18\x8cy\x12\xb3\x80\x91\xc9P\xe2\xca5\xd8\xc4\x0f\x18\x80!\x894\xa8\x0c Jm\x07\x82\xe2$\x19\xbb?\x11-\xff\xf1\xcc\n\xa3\x83\xe9\x13)\x0c)N\x04e\xfe\x9e\xacv,\xfd\xad\xe8w\xabU\xb5\xda\xcc\x06\xc7q\xdd\xff\xff\xff\xff\xff\xff\xd4\xf2\xcd\x94\x85wgT\xc1\xe4\x8d\xf2\x9c^\xd3*\x83G$1\x02>\xa5\x17K4\xff\xfbR\xc4\x05\x00\n\xc4\xe5{\xcc\xac\xed\xb1\x92\xab\xad=\x83\x8aa\xb5$$\x8c\x88e\x0f\r.R\xf3\xafd\x99})^6\xc4\xfc\xa7\xc1\x89\xdc\x9f\xcb\xfe\x193wN\xe7k\x12\x95\x04\xaeq\x8b,\x87Mc\xcd\x84\xed\xff\xff\xefO\xfe\xc8f\xe6\xe5T\x8d\xae\xcaS\xfb\xf2\x1f\xffx\xcb\xdaD\x93\x9a\x15\xbd\xa8\x86\xd5\x00H\x18\x1a\x80\x01\x1b\x04V\xad\xf0\xb9;\xeaN\x89\xd5\x82[\xfdh\xec\xf6<\xb9\xd5\xf5\xbd\xaaNq\x99Y\xd2\xb3K3\x96\xdfR\x04\xe7\xb6^Q\xfd\t\x9e \x0c\x94\x97\x95\x9a\\^\xec<\xdf\xfa\xebD\xa1\x8a\xff\xec\x0c\x8a\xa1\xc1\x11\xfa\x1e\xb6(\x1a+3\xfb7\xea\xdfu\x97\xff\xff\xfeCT\x8cEs\x83\xb8\x8cF\x19\xe2\xaa\xd3\xd9V\xe6%\x11\t\xc2C\x00\x97\x16.[\xff\xfbR\xc4\x05\x80\x0b\xb1au\xac(M\xb1t-nt\xf7\x88\xfet&k\x88\x824\x9a\xb7J\xadP\xf3\x01F\x8b7\x00\xdd\xc68/\x89\xae\x1e\x1d\x19eOB\x83\xb1\x93\xfa\x938\xf8R\x93\xaa4cF\xa8_\xfbY\xea\xf4\xb4\x7f\xfe|\x88\xc0\xdf1\xe5)\x10\xf0\xaf\xfd\xff\xf9\xfdt?\xff\xff]\x1arPyG\x87\x968\xcd\xc9)`\xecTm\x10e "\te\xf8\x16`\xe0\x06\xab\x ...

# %%
def write(prompt: str):
    for chunk in openai.ChatCompletion.create(
        model= "gpt-3.5-turbo",
        messages = [{ "role": "user", "content": prompt}],
        stream = True,
    ):
        if(text_chung := chunk["choices"][0]["delta"].get("content")) is not None:
            yield text_chunk

text_stream = write("A one-sentence relaxing speech.")

audio_stream = elevenlabs.generate(
    text=text_stream,
    voice="Nicole",
    stream = True,
)
output = elevenlabs.stream(audio_stream)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 17
#      10 text_stream = write("A one-sentence relaxing speech.")
#      12 audio_stream = elevenlabs.generate(
#      13     text=text_stream,
#      14     voice="Nicole",
#      15     stream = True,
#      16 )
# ---> 17 output = elevenlabs.stream(audio_stream)
#
# File ~/anaconda3/lib/python3.10/site-packages/elevenlabs/utils.py:62, in stream(audio_stream)
#      56 if not is_installed("mpv"):
#      57     message = (
#      58         "mpv not found, necessary to stream audio. "
#      59         "On mac you can install it with 'brew install mpv'. "
#      60         "On linux and windows you can install it from https://mpv.io/"
#      61     )
# ---> 62     raise ValueError(message)
#      64 mpv_command = ["mpv", "--no-cache", "--no-terminal", "--", "fd://0"]
#      65 mpv_process = subprocess.Popen(
#      66     mpv_command,
#      67     stdin=subprocess.PIPE,
#      68     stdout=subprocess.DEVNULL,
#      69     stderr=subprocess.DEVNULL,
#      70 )
#
# ValueError: mpv not found, necessary to stream audio. On mac you can install it with 'brew install mpv'. On linux and windows you can install it from https://mpv.io/
