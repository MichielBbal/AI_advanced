# %% [markdown]
# # Using Ollama with Langchain
#
# Please install ollama first from www.ollama.ai with LLaMa2.
#
# Then run the notebook.

# %% [markdown]
# ## 0. Install, check version & import

# %%
#!pip install -U langchain

# %%
langchain.__version__
# Out:
# '0.0.339'

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.0.339
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages
# Requires: aiohttp, anyio, async-timeout, dataclasses-json, jsonpatch, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
import langchain
from langchain import llms

# %%
#check all available LLM's
print(dir(llms))
# Out:
# ['Any', 'BaseLLM', 'Callable', 'Dict', 'Type', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__getattr__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_import_ai21', '_import_aleph_alpha', '_import_amazon_api_gateway', '_import_anthropic', '_import_anyscale', '_import_arcee', '_import_aviary', '_import_azure_openai', '_import_azureml_endpoint', '_import_baidu_qianfan_endpoint', '_import_bananadev', '_import_baseten', '_import_beam', '_import_bedrock', '_import_bittensor', '_import_cerebriumai', '_import_chatglm', '_import_clarifai', '_import_cohere', '_import_ctransformers', '_import_ctranslate2', '_import_databricks', '_import_deepinfra', '_import_deepsparse', '_import_edenai', '_import_fake', '_import_fireworks', '_import_forefrontai', '_import_gigachat', '_import_google_palm', '_import_gooseai', '_import_gpt4all', '_import_gradient_ai', '_import_huggingface_endpoint', '_import_huggingface_hub', '_import_huggingface_pipeline', '_import_huggi
# ...

# %%
#import package
from langchain.llms import Ollama

# %% [markdown]
# ## 1. First script
#
# Please make sure you have installed Llama2 on your device (locally)

# %%
# %%time
from langchain.llms import Ollama
ollama = Ollama(base_url='http://localhost:11434',
model="llama2")
print(ollama("why is the sky blue"))
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering. When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen. These molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer (red) wavelengths.
#
# This is known as Rayleigh scattering, named after the English physicist Lord Rayleigh, who first described the phenomenon in the late 19th century. The scattered light then reaches our eyes, giving the sky its blue color.
#
# The reason for this selective scattering of light has to do with the size of the molecules in the atmosphere and the wavelength of the light. The smaller the molecule, the more it scatters shorter wavelengths of light. Nitrogen and oxygen are the two main gases responsible for the blue color of the sky, and they have molecular sizes that are large enough to scatter shorter wavelengths more than longer ones.
#
# ...

# %%
# !ollama run mistral
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling 6ae280299950...   0% ▕    ▏(0 B/4.1 GB)                                pulling manifest
# pulling 6ae280299950...   0% ▕    ▏(0 B/4.1 GB)                                pulling manifest
# pulling 6ae280299950...   0% ▕    ▏(0 B/4.1 GB)                                pulling manifest
# pulling 6ae280299950...   0% ▕    ▏(0 B/4.1 GB)                                pulling manifest
# pulling 6ae280299950...   0% ▕    ▏(0 B/4.1 GB)                                pulling manifest
# ...

# %%
# %%time
from langchain.llms import Ollama
ollama = Ollama(base_url='http://localhost:11434',
model="mistral")
print(ollama("why is the sky blue"))
# Out:
# The color of the sky appears blue because of a phenomenon known as Rayleigh scattering. When sunlight reaches Earth's atmosphere, it encounters particles such as nitrogen and oxygen molecules, which scatter the light in all directions. The shorter wavelengths of light, such as violet and blue, are scattered more readily than the longer wavelengths, such as red and orange. This causes the blue light to dominate the sky's appearance, especially during the day when the sun is high in the sky. However, at dawn and dusk, when the sun is low on the horizon, the shorter wavelengths of light are scattered more easily by the atmosphere, causing the sky to appear red or orange.
# CPU times: user 48.5 ms, sys: 71.8 ms, total: 120 ms
# Wall time: 1min 55s
