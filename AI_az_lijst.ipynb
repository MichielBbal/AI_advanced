# %%
import requests

url = 'https://student.hva.nl/studenten-algemeen/a-z.html'

download = requests.get(url)

# %%
download
# Out:
# <Response [200]>

# %%
download.text
# Out:
# '<!DOCTYPE html>\n<!--[if gt IE 8]> <html class="no-js"><![endif]-->\n<html xml:lang="nl" lang="nl" xmlns="http://www.w3.org/1999/xhtml" class="no-js">\n<head>\n    <meta charset="utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n    <title>A-Z studenten algemeen - Hogeschool van Amsterdam</title>\n<meta property="og:title" content="A-Z studenten algemeen - Hogeschool van Amsterdam" />\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="@HvA">\n<meta name="twitter:title" content="A-Z studenten algemeen - Hogeschool van Amsterdam">\n<meta name="twitter:creator" content="@HvA">\n<meta name="twitter:domain" content="student.hva.nl">\n<meta name="twitter:description" content="A-Z studenten algemeen - Hogeschool van Amsterdam">\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n    <link rel="stylesheet" href="/webfiles/1678260110403/css/style.css" />\n    <link rel="stylesheet" href="//maxcdn.b
# ...

# %%
page = 'https://student.hva.nl/az-lemmas/studenten/hva-breed/ac-hr/adres-wijzigen/adres-wijzigen.html?origin=%2BIhoMBbOSD%2BbG%2BOeXCnbzQ'
page_download = requests.get(page)
page_download.text
# Out:
# '<!DOCTYPE html>\n<!--[if gt IE 8]> <html class="no-js"><![endif]-->\n<html xml:lang="nl" lang="nl" xmlns="http://www.w3.org/1999/xhtml" class="no-js">\n<head>\n    <meta charset="utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n    <title>Adres wijzigen - Hogeschool van Amsterdam</title>\n<meta property="og:title" content="Adres wijzigen - Hogeschool van Amsterdam" />\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="@HvA">\n<meta name="twitter:title" content="Adres wijzigen - Hogeschool van Amsterdam">\n<meta name="twitter:creator" content="@HvA">\n<meta name="twitter:domain" content="student.hva.nl">\n<meta name="twitter:description" content="Adres wijzigen - Hogeschool van Amsterdam">\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n    <link rel="stylesheet" href="/webfiles/1678260110403/css/style.css" />\n    <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/font-awesome/4.5
# ...
